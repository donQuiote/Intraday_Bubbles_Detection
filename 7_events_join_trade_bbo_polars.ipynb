# %% [markdown]
# # Merging trades and bbos with polars
#
# The data for SPY.P covers 2 years (2009 and 2010).

# %%
import polars as pl
import numpy as np

import os

dirData_raw = "data/raw/TRTH/equities/US/"
dirData_clean = dirData_raw.replace("raw","clean")

ticker = "SPY.P"

bbo   = pl.scan_parquet(dirData_clean+"/bbo/"+ticker+"_bbo.parquet").sort('index')
trade = pl.scan_parquet(dirData_clean+"/trade/"+ticker+"_trade.parquet").sort('index')

events = bbo.join(trade,on='index',how="full",coalesce=True).sort('index')

events = events.with_columns(pl.col('index').dt.date().alias('date'))
events = events.with_columns([pl.col('bid-price').forward_fill().over('date'),
                              pl.col('bid-volume').forward_fill().over('date'),
                              pl.col('ask-price').forward_fill().over('date'),
                              pl.col('ask-volume').forward_fill().over('date')])
events
# Out:
# <h4>NAIVE QUERY PLAN</h4><p>run <b>LazyFrame.show_graph()</b> to see the optimized version</p><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: polars_query Pages: 1 -->
# <svg width="1276pt" height="423pt"
#  viewBox="0.00 0.00 1276.00 423.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 419)">
# <title>polars_query</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-419 1272,-419 1272,4 -4,4"/>
# <!-- p1 -->
# <g id="node1" class="node">
# <title>p1</title>
# <polygon fill="none" stroke="black" points="1268,-415 0,-415 0,-379 1268,-379 1268,-415"/>
# <text text-anchor="middle" x="634" y="-393.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [col(&quot;bid&#45;price&quot;).forward_fill().over([col(&quot;date&quot;)]), col(&quot;bid&#45;volume&quot;).forward_fill().over([col(&quot;date&quot;)]), col(&quot;ask&#45;price&quot;).forward_fill().over([col(&quot;date&quot;)]), col(&quot;ask&#45;volume&quot;).forward_fill().over([col(&quot;date&quot;)])]</text>
# </g>
# <!-- p2 -->
# <g id="node2" class="node">
# <title>p2</title>
# <polygon fill="none" stroke="black" points="796.5,-343 471.5,-343 471.5,-307 796.5,-307 796.5,-343"/>
# <text text-anchor="middle" x="634" y="-321.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [col(&quot;index&quot;).dt.date().alias(&quot;date&quot;)]</text>
# </g>
# <!-- p1&#45;&#45;p2 -->
# <g id="edge1" class="edge">
# <title>p1&#45;&#45;p2</title>
# <path fill="none" stroke="black" d="M634,-378.7C634,-367.85 634,-353.92 634,-343.1"/>
# </g>
# <!-- p3 -->
# <g id="node3" class="node">
# <title>p3</title>
# <polygon fill="none" stroke="black" points="710,-271 558,-271 558,-235 710,-235 710,-271"/>
# <text text-anchor="middle" x="634" y="-249.3" font-family="Times,serif" font-size="14.00">SORT BY [col(&quot;index&quot;)]</text>
# </g>
# <!-- p2&#45;&#45;p3 -->
# <g id="edge2" class="edge">
# <title>p2&#45;&#45;p3</title>
# <path fill="none" stroke="black" d="M634,-306.7C634,-295.85 634,-281.92 634,-271.1"/>
# </g>
# <!-- p4 -->
# <g id="node4" class="node">
# <title>p4</title>
# <polygon fill="none" stroke="black" points="697,-199 571,-199 571,-146 697,-146 697,-199"/>
# <text text-anchor="middle" x="634" y="-183.8" font-family="Times,serif" font-size="14.00">JOIN FULL</text>
# <text text-anchor="middle" x="634" y="-168.8" font-family="Times,serif" font-size="14.00">left: [col(&quot;index&quot;)];</text>
# <text text-anchor="middle" x="634" y="-153.8" font-family="Times,serif" font-size="14.00">right: [col(&quot;index&quot;)]</text>
# </g>
# <!-- p3&#45;&#45;p4 -->
# <g id="edge3" class="edge">
# <title>p3&#45;&#45;p4</title>
# <path fill="none" stroke="black" d="M634,-234.97C634,-224.51 634,-210.9 634,-199.16"/>
# </g>
# <!-- p5 -->
# <g id="node5" class="node">
# <title>p5</title>
# <polygon fill="none" stroke="black" points="560,-110 408,-110 408,-74 560,-74 560,-110"/>
# <text text-anchor="middle" x="484" y="-88.3" font-family="Times,serif" font-size="14.00">SORT BY [col(&quot;index&quot;)]</text>
# </g>
# <!-- p4&#45;&#45;p5 -->
# <g id="edge4" class="edge">
# <title>p4&#45;&#45;p5</title>
# <path fill="none" stroke="black" d="M584.88,-145.8C562.5,-134.08 536.61,-120.53 516.66,-110.09"/>
# </g>
# <!-- p7 -->
# <g id="node7" class="node">
# <title>p7</title>
# <polygon fill="none" stroke="black" points="861,-110 709,-110 709,-74 861,-74 861,-110"/>
# <text text-anchor="middle" x="785" y="-88.3" font-family="Times,serif" font-size="14.00">SORT BY [col(&quot;index&quot;)]</text>
# </g>
# <!-- p4&#45;&#45;p7 -->
# <g id="edge6" class="edge">
# <title>p4&#45;&#45;p7</title>
# <path fill="none" stroke="black" d="M683.44,-145.8C705.98,-134.08 732.04,-120.53 752.12,-110.09"/>
# </g>
# <!-- p6 -->
# <g id="node6" class="node">
# <title>p6</title>
# <polygon fill="none" stroke="black" points="622.5,-38 215.5,-38 215.5,0 622.5,0 622.5,-38"/>
# <text text-anchor="middle" x="419" y="-22.8" font-family="Times,serif" font-size="14.00">Parquet SCAN [data/clean/TRTH/equities/US//bbo/SPY.P_bbo.parquet]</text>
# <text text-anchor="middle" x="419" y="-7.8" font-family="Times,serif" font-size="14.00">π */5;</text>
# </g>
# <!-- p5&#45;&#45;p6 -->
# <g id="edge5" class="edge">
# <title>p5&#45;&#45;p6</title>
# <path fill="none" stroke="black" d="M468.27,-73.81C458.35,-62.98 445.56,-49.01 435.5,-38.02"/>
# </g>
# <!-- p8 -->
# <g id="node8" class="node">
# <title>p8</title>
# <polygon fill="none" stroke="black" points="1061.5,-38 640.5,-38 640.5,0 1061.5,0 1061.5,-38"/>
# <text text-anchor="middle" x="851" y="-22.8" font-family="Times,serif" font-size="14.00">Parquet SCAN [data/clean/TRTH/equities/US//trade/SPY.P_trade.parquet]</text>
# <text text-anchor="middle" x="851" y="-7.8" font-family="Times,serif" font-size="14.00">π */3;</text>
# </g>
# <!-- p7&#45;&#45;p8 -->
# <g id="edge7" class="edge">
# <title>p7&#45;&#45;p8</title>
# <path fill="none" stroke="black" d="M800.98,-73.81C811.05,-62.98 824.03,-49.01 834.25,-38.02"/>
# </g>
# </g>
# </svg>

# %%
file_events = dirData_clean+"/"+ticker+"_events.parquet"
events.collect(streaming=True).write_parquet(file_events)

# %% [markdown]
# How many lines, though?

# %%
pl.scan_parquet(file_events).select(pl.len()).collect()
# Out:
# shape: (1, 1)
# ┌───────────┐
# │ len       │
# │ ---       │
# │ u32       │
# ╞═══════════╡
# │ 188758365 │
# └───────────┘

# %% [markdown]
# And about 1GB (compressed with zstd)

# %%
import os
os.path.getsize(file_events)//2**20
# Out:
# 945

# %% [markdown]
# In some occasions, we do not need all the quotes between the trades. Let us generate a simpler event df.

# %%
bbo   = pl.scan_parquet(dirData_clean+"/bbo/"+ticker+"_bbo.parquet").sort('index')
trade = pl.scan_parquet(dirData_clean+"/trade/"+ticker+"_trade.parquet").sort('index')

events = bbo.join(trade,on='index',how="full",coalesce=True).sort('index')

events = events.with_columns(pl.col('index').dt.date().alias('date'))
events = events.with_columns([pl.col('bid-price').forward_fill().over('date'),
                              pl.col('bid-volume').forward_fill().over('date'),
                              pl.col('ask-price').forward_fill().over('date'),
                              pl.col('ask-volume').forward_fill().over('date')])
events = events.drop_nulls()   
events
# Out:
# <h4>NAIVE QUERY PLAN</h4><p>run <b>LazyFrame.show_graph()</b> to see the optimized version</p><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: polars_query Pages: 1 -->
# <svg width="1713pt" height="495pt"
#  viewBox="0.00 0.00 1713.00 495.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 491)">
# <title>polars_query</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-491 1709,-491 1709,4 -4,4"/>
# <!-- p1 -->
# <g id="node1" class="node">
# <title>p1</title>
# <polygon fill="none" stroke="black" points="1705,-487 0,-487 0,-451 1705,-451 1705,-487"/>
# <text text-anchor="middle" x="852.5" y="-465.3" font-family="Times,serif" font-size="14.00">FILTER BY [([([([([([([(col(&quot;index&quot;).is_not_null()) &amp; (col(&quot;bid&#45;price&quot;).is_not_null())]) &amp; (col(&quot;bid&#45;volume&quot;).is_not_null())]) &amp; (col(&quot;ask&#45;price&quot;).is_not_null())]) &amp; (col(&quot;ask&#45;volume&quot;).is_not_null())]) &amp; (col(&quot;trade&#45;price&quot;).is_not_null())]) &amp; (col(&quot;trade&#45;volume&quot;).is_not_null())]) &amp; (col(&quot;date&quot;).is_not_null())]</text>
# </g>
# <!-- p2 -->
# <g id="node2" class="node">
# <title>p2</title>
# <polygon fill="none" stroke="black" points="1486.5,-415 218.5,-415 218.5,-379 1486.5,-379 1486.5,-415"/>
# <text text-anchor="middle" x="852.5" y="-393.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [col(&quot;bid&#45;price&quot;).forward_fill().over([col(&quot;date&quot;)]), col(&quot;bid&#45;volume&quot;).forward_fill().over([col(&quot;date&quot;)]), col(&quot;ask&#45;price&quot;).forward_fill().over([col(&quot;date&quot;)]), col(&quot;ask&#45;volume&quot;).forward_fill().over([col(&quot;date&quot;)])]</text>
# </g>
# <!-- p1&#45;&#45;p2 -->
# <g id="edge1" class="edge">
# <title>p1&#45;&#45;p2</title>
# <path fill="none" stroke="black" d="M852.5,-450.7C852.5,-439.85 852.5,-425.92 852.5,-415.1"/>
# </g>
# <!-- p3 -->
# <g id="node3" class="node">
# <title>p3</title>
# <polygon fill="none" stroke="black" points="1015,-343 690,-343 690,-307 1015,-307 1015,-343"/>
# <text text-anchor="middle" x="852.5" y="-321.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [col(&quot;index&quot;).dt.date().alias(&quot;date&quot;)]</text>
# </g>
# <!-- p2&#45;&#45;p3 -->
# <g id="edge2" class="edge">
# <title>p2&#45;&#45;p3</title>
# <path fill="none" stroke="black" d="M852.5,-378.7C852.5,-367.85 852.5,-353.92 852.5,-343.1"/>
# </g>
# <!-- p4 -->
# <g id="node4" class="node">
# <title>p4</title>
# <polygon fill="none" stroke="black" points="928.5,-271 776.5,-271 776.5,-235 928.5,-235 928.5,-271"/>
# <text text-anchor="middle" x="852.5" y="-249.3" font-family="Times,serif" font-size="14.00">SORT BY [col(&quot;index&quot;)]</text>
# </g>
# <!-- p3&#45;&#45;p4 -->
# <g id="edge3" class="edge">
# <title>p3&#45;&#45;p4</title>
# <path fill="none" stroke="black" d="M852.5,-306.7C852.5,-295.85 852.5,-281.92 852.5,-271.1"/>
# </g>
# <!-- p5 -->
# <g id="node5" class="node">
# <title>p5</title>
# <polygon fill="none" stroke="black" points="915.5,-199 789.5,-199 789.5,-146 915.5,-146 915.5,-199"/>
# <text text-anchor="middle" x="852.5" y="-183.8" font-family="Times,serif" font-size="14.00">JOIN FULL</text>
# <text text-anchor="middle" x="852.5" y="-168.8" font-family="Times,serif" font-size="14.00">left: [col(&quot;index&quot;)];</text>
# <text text-anchor="middle" x="852.5" y="-153.8" font-family="Times,serif" font-size="14.00">right: [col(&quot;index&quot;)]</text>
# </g>
# <!-- p4&#45;&#45;p5 -->
# <g id="edge4" class="edge">
# <title>p4&#45;&#45;p5</title>
# <path fill="none" stroke="black" d="M852.5,-234.97C852.5,-224.51 852.5,-210.9 852.5,-199.16"/>
# </g>
# <!-- p6 -->
# <g id="node6" class="node">
# <title>p6</title>
# <polygon fill="none" stroke="black" points="778.5,-110 626.5,-110 626.5,-74 778.5,-74 778.5,-110"/>
# <text text-anchor="middle" x="702.5" y="-88.3" font-family="Times,serif" font-size="14.00">SORT BY [col(&quot;index&quot;)]</text>
# </g>
# <!-- p5&#45;&#45;p6 -->
# <g id="edge5" class="edge">
# <title>p5&#45;&#45;p6</title>
# <path fill="none" stroke="black" d="M803.38,-145.8C781,-134.08 755.11,-120.53 735.16,-110.09"/>
# </g>
# <!-- p8 -->
# <g id="node8" class="node">
# <title>p8</title>
# <polygon fill="none" stroke="black" points="1079.5,-110 927.5,-110 927.5,-74 1079.5,-74 1079.5,-110"/>
# <text text-anchor="middle" x="1003.5" y="-88.3" font-family="Times,serif" font-size="14.00">SORT BY [col(&quot;index&quot;)]</text>
# </g>
# <!-- p5&#45;&#45;p8 -->
# <g id="edge7" class="edge">
# <title>p5&#45;&#45;p8</title>
# <path fill="none" stroke="black" d="M901.94,-145.8C924.48,-134.08 950.54,-120.53 970.62,-110.09"/>
# </g>
# <!-- p7 -->
# <g id="node7" class="node">
# <title>p7</title>
# <polygon fill="none" stroke="black" points="841,-38 434,-38 434,0 841,0 841,-38"/>
# <text text-anchor="middle" x="637.5" y="-22.8" font-family="Times,serif" font-size="14.00">Parquet SCAN [data/clean/TRTH/equities/US//bbo/SPY.P_bbo.parquet]</text>
# <text text-anchor="middle" x="637.5" y="-7.8" font-family="Times,serif" font-size="14.00">π */5;</text>
# </g>
# <!-- p6&#45;&#45;p7 -->
# <g id="edge6" class="edge">
# <title>p6&#45;&#45;p7</title>
# <path fill="none" stroke="black" d="M686.77,-73.81C676.85,-62.98 664.06,-49.01 654,-38.02"/>
# </g>
# <!-- p9 -->
# <g id="node9" class="node">
# <title>p9</title>
# <polygon fill="none" stroke="black" points="1280,-38 859,-38 859,0 1280,0 1280,-38"/>
# <text text-anchor="middle" x="1069.5" y="-22.8" font-family="Times,serif" font-size="14.00">Parquet SCAN [data/clean/TRTH/equities/US//trade/SPY.P_trade.parquet]</text>
# <text text-anchor="middle" x="1069.5" y="-7.8" font-family="Times,serif" font-size="14.00">π */3;</text>
# </g>
# <!-- p8&#45;&#45;p9 -->
# <g id="edge8" class="edge">
# <title>p8&#45;&#45;p9</title>
# <path fill="none" stroke="black" d="M1019.48,-73.81C1029.55,-62.98 1042.53,-49.01 1052.75,-38.02"/>
# </g>
# </g>
# </svg>

# %%
file_events_short = dirData_clean+"/"+ticker+"_events_short.parquet"

events.collect(streaming=True).write_parquet(file_events_short)

# %%
pl.scan_parquet(file_events_short).select(pl.len()).collect()
# Out:
# shape: (1, 1)
# ┌──────────┐
# │ len      │
# │ ---      │
# │ u32      │
# ╞══════════╡
# │ 18589042 │
# └──────────┘

# %% [markdown]
# A more manageable file size:

# %%
import os
os.path.getsize(file_events_short)//(2**20)
# Out:
# 146
